# %% [markdown]
# # Proyecto SQL - Videoclub ABC

# %% [markdown]
# Importamos librerias

# %%
import pandas as pd
import numpy as np
import re
import random

pd.set_option('display.max_columns', None)

# para pintar
import pylab as plt
import seaborn as sns

# para que salga el grafico
# %matplotlib inline

# %% [markdown]
# Leer CSVs

# %%
actors_raw = pd.read_csv('data/actor.csv')
category_raw = pd.read_csv('data/category.csv')
film_raw = pd.read_csv('data/film.csv')
inventory_raw = pd.read_csv('data/inventory.csv')
language_raw = pd.read_csv('data/language.csv')
old_HDD_raw = pd.read_csv('data/old_HDD.csv')
rental_raw = pd.read_csv('data/rental.csv')

# %% [markdown]
# Crear copia

# %%
actors = actors_raw.copy()
cat = category_raw.copy()
fil = film_raw.copy()
inv = inventory_raw.copy()
old = old_HDD_raw.copy()
ren = rental_raw.copy()

# %% [markdown]
# Revisamos tabla ACTORS:

# %%
actors
# Out:
#      actor_id first_name     last_name          last_update
# 0           1   PENELOPE       GUINESS  2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG  2006-02-15 04:34:33
# 2           3         ED         CHASE  2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS  2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA  2006-02-15 04:34:33
# ..        ...        ...           ...                  ...
# 195       196       BELA        WALKEN  2006-02-15 04:34:33
# 196       197      REESE          WEST  2006-02-15 04:34:33
# 197       198       MARY        KEITEL  2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT  2006-02-15 04:34:33
# 199       200      THORA        TEMPLE  2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
actors.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   actor_id     200 non-null    int64
#  1   first_name   200 non-null    object
#  2   last_name    200 non-null    object
#  3   last_update  200 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 41.0 KB

# %%
actors.actor_id.value_counts()
# Out:
# 1      1
# 138    1
# 128    1
# 129    1
# 130    1
#       ..
# 70     1
# 71     1
# 72     1
# 73     1
# 200    1
# Name: actor_id, Length: 200, dtype: int64

# %%
actors.first_name.value_counts()
# Out:
# PENELOPE    4
# JULIA       4
# KENNETH     4
# GENE        3
# GROUCHO     3
#            ..
# HENRY       1
# DUSTIN      1
# JUDE        1
# CARMEN      1
# THORA       1
# Name: first_name, Length: 128, dtype: int64

# %%
actors.last_name.value_counts()
# Out:
# KILMER     5
# TEMPLE     4
# NOLTE      4
# GUINESS    3
# ALLEN      3
#           ..
# JOLIE      1
# DAMON      1
# CRUZ       1
# SINATRA    1
# WALKEN     1
# Name: last_name, Length: 121, dtype: int64

# %%
actors.last_update.value_counts()
# Out:
# 2006-02-15 04:34:33    200
# Name: last_update, dtype: int64

# %%
(actors.first_name + ' ' + actors.last_name).value_counts() > 1
# Out:
# SUSAN DAVIS              True
# EWAN GOODING            False
# DARYL CRAWFORD          False
# GRETA KEITEL            False
# JANE JACKMAN            False
#                         ...
# MICHELLE MCCONAUGHEY    False
# ADAM GRANT              False
# SEAN WILLIAMS           False
# GARY PENN               False
# THORA TEMPLE            False
# Length: 199, dtype: bool

# %%
actors[actors.first_name == 'SUSAN']
# Out:
#      actor_id first_name last_name          last_update
# 100       101      SUSAN     DAVIS  2006-02-15 04:34:33
# 109       110      SUSAN     DAVIS  2006-02-15 04:34:33

# %% [markdown]
# H0: Actriz repetida
# H1: Distintas actrices con un mismo nombre

# %% [markdown]
# Columna ACTORS limpia ✅

# %% [markdown]
# Revisamos tabla CATEGORY

# %%
category
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13912\1425997787.py in <module>
# ----> 1 category
#
# NameError: name 'category' is not defined

# %%
cat

# %%
cat.name ==

# %%
category.info(memory_usage='deep')

# %%
category.category_id.value_counts()

# %%
category.name.value_counts()

# %%
category.last_update.value_counts()

# %% [markdown]
# Columna CATEGORY limpia ✅

# %% [markdown]
# Revisamos tabla FILM

# %%
film

# %%
film.info(memory_usage='deep')

# %%
film.film_id.value_counts()

# %% [markdown]
# film_ID va ordenado de 1 a 1000 por el orden alfabético del nombre de la película

# %%
film.title.value_counts()

# %%
film.description.value_counts()

# %%
film.release_year.value_counts()

# %%
film.language_id.value_counts()

# %% [markdown]
# film.language_id tiene todo unos, anotado.

# %%
film.original_language_id.value_counts()

# %% [markdown]
# Todo NULL, anotado también

# %%
film.rental_duration.value_counts()

# %%
film.rental_rate.value_counts()

# %%
film.length.value_counts()

# %%
film.replacement_cost.value_counts()

# %%
film.replacement_cost.value_counts()

# %%
film.rating.value_counts()

# %%
film.special_features.value_counts()

# %%
film.last_update.value_counts()

# %% [markdown]
# Columna FILM limpia ✅

# %% [markdown]
# Revisamos tabla INVENTORY

# %%
np.array(range(1,ren.inventory_id.max())).T
# Out:
# array([   1,    2,    3, ..., 4578, 4579, 4580])

# %%
inv_total = pd.DataFrame(list(range(1,ren.inventory_id.max())), columns = ['inventory_id'])
inv_total
# Out:
#       inventory_id
# 0                1
# 1                2
# 2                3
# 3                4
# 4                5
# ...            ...
# 4575          4576
# 4576          4577
# 4577          4578
# 4578          4579
# 4579          4580
#
# [4580 rows x 1 columns]

# %%
inv_total = pd.DataFrame(list(range(1,ren.inventory_id.max())), columns = ['inventory_id'])
inv_final = pd.merge(inv_total, inv, how="left", on="inventory_id")
inv_final
# Out:
#       inventory_id  film_id  store_id          last_update
# 0                1      1.0       1.0  2006-02-15 05:09:17
# 1                2      1.0       1.0  2006-02-15 05:09:17
# 2                3      1.0       1.0  2006-02-15 05:09:17
# 3                4      1.0       1.0  2006-02-15 05:09:17
# 4                5      1.0       2.0  2006-02-15 05:09:17
# ...            ...      ...       ...                  ...
# 4575          4576      NaN       NaN                  NaN
# 4576          4577      NaN       NaN                  NaN
# 4577          4578      NaN       NaN                  NaN
# 4578          4579      NaN       NaN                  NaN
# 4579          4580      NaN       NaN                  NaN
#
# [4580 rows x 4 columns]

# %%
pd.set_option('display.max_rows', 1100)

# %%
inv_final.head(1100)
# Out:
#       inventory_id  film_id  store_id          last_update
# 0                1      1.0       1.0  2006-02-15 05:09:17
# 1                2      1.0       1.0  2006-02-15 05:09:17
# 2                3      1.0       1.0  2006-02-15 05:09:17
# 3                4      1.0       1.0  2006-02-15 05:09:17
# 4                5      1.0       2.0  2006-02-15 05:09:17
# 5                6      1.0       2.0  2006-02-15 05:09:17
# 6                7      1.0       2.0  2006-02-15 05:09:17
# 7                8      1.0       2.0  2006-02-15 05:09:17
# 8                9      2.0       2.0  2006-02-15 05:09:17
# 9               10      2.0       2.0  2006-02-15 05:09:17
# 10              11      2.0       2.0  2006-02-15 05:09:17
# 11              12      3.0       2.0  2006-02-15 05:09:17
# 12              13      3.0       2.0  2006-02-15 05:09:17
# 13              14      3.0       2.0  2006-02-15 05:09:17
# 14              15      3.0       2.0  2006-02-15 05:09:17
# ...

# %%
inv.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   inventory_id  1000 non-null   int64
#  1   film_id       1000 non-null   int64
#  2   store_id      1000 non-null   int64
#  3   last_update   1000 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 97.8 KB

# %%
inventory.inventory_id.value_counts()

# %%
inventory.film_id.value_counts()

# %% [markdown]
# Inventory solo tiene las peliculas con los primeros 223 IDs

# %%
inventory.store_id.value_counts()

# %%
inventory.last_update.value_counts()

# %% [markdown]
# Columna INVENTORY limpia ✅

# %% [markdown]
# Revisamos tabla LANGUAGE

# %%
language

# %%
language.info(memory_usage='deep')

# %%
language.language_id.value_counts()

# %%
language.name.value_counts()

# %%
language.last_update.value_counts()

# %% [markdown]
# Columna LANGUAGE limpia ✅

# %% [markdown]
# Revisamos tabla OLD_HDD

# %%
old

# %%
old.info(memory_usage='deep')

# %%
old.describe()

# %%
old.first_name.value_counts()

# %%
old.last_name.value_counts()

# %%
old.title.value_counts()

# %%
pd.set_option('display.max_rows', 30)
old

# %%
old.release_year.value_counts()

# %%
old.category_id.value_counts()

# %% [markdown]
# Columna OLD limpia ✅

# %% [markdown]
# Revisamos tabla RENTAL

# %%
pd.set_option('display.max_rows', 2)
ren
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367          130
# ..         ...                  ...           ...          ...
# 999       1001  2005-05-31 00:46:31          1498           64
#
#              return_date  staff_id          last_update
# 0    2005-05-26 22:04:30         1  2006-02-15 21:30:53
# ..                   ...       ...                  ...
# 999  2005-06-06 06:14:31         2  2006-02-15 21:30:53
#
# [1000 rows x 7 columns]

# %%
ren.inventory_id.max()
# Out:
# 4581

# %%
rental.info(memory_usage='deep')

# %%
year = []
for i in ren.rental_date:
    year.append(i[0:4])
set(year)
# Out:
# {'2005'}

# %% [markdown]
# Apreciar que se saltan un ID en rental ID

# %%
print(list(ren.rental_id[ren.index==ren.rental_id -1])[-1])
print(list(ren.rental_id[ren.index==ren.rental_id -2])[0])
# Out:
# 320
# 322

# %%
list(rental.rental_id[rental.index==rental.rental_id -1])[-1]

# %% [markdown]
# Falta el índice 321

# %%
old.index

# %%
fil.rename({'language_id': 'language'}, axis=1, inplace=True) # cambiar el nombre de la columna language
fil.language = 'English' #que todos los language sean English
fil.release_year = '' #vaciar release year porque está vacia
fil = fil.drop('last_update', axis = 1) #quitamos last_update

# %%
fil['actores'] = '' #creamos columna vacía


def actores(peli): #creamos función que saque los actores de esa peli
    act = []
    for i in old.index:
        if old.title[i] == peli:
            name = old.first_name[i] + ' ' + old.last_name[i]
            act.append(name)
    return ', '.join(act)

#los introducimos por cada fila
for i in fil.index:
    fil['actores'][i] = actores(fil.title[i])

# %%
fil['category'] = '' #creamos columna vacía

def categ(peli):  #creamos función que saque la categoría de esa peli
    categor = ''
    for i in old.index:
        if old.title[i] == peli:
            categor = cat[cat.category_id == old.category_id[i]].name.iloc[0]
            return categor

#Introducimos la categoría en cada fila
for i in fil.index: 
    fil['category'][i] = categ(fil.title[i])

# %%
cat[cat.category_id == 5].name.iloc[0]

# %%
fil.category.value_counts().sum()

# %%
fil

# %%
[*zip(*map(old.get, old))]

# %%
#fil_meteme = [*zip(*map(fil.get, fil))]

# %%
values = ', '.join(map(str, [*zip(*map(fil.get, fil))] ))

# %%
values

# %%
sql = "INSERT INTO old VALUES {}".format(values)
